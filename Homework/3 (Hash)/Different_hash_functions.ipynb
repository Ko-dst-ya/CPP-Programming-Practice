RS_data=[(10,0),
(50010,0),
(100010,1),
(150010,3),
(200010,4),
(250010,7),
(300010,8),
(350010,13),
(400010,16),
(450010,27),
(500010,35),
(550010,41),
(600010,43),
(650010,43),
(700010,51),
(750010,84),
(800010,71),
(850010,91),
(900010,98),
(950010,97)]

# %%
JSH_data = [(10,0),
(50010,1),
(100010,0),
(150010,4),
(200010,2),
(250010,8),
(300010,9),
(350010,14),
(400010,19),
(450010,19),
(500010,23),
(550010,26),
(600010,41),
(650010,60),
(700010,57),
(750010,71),
(800010,84),
(850010,94),
(900010,81),
(950010,109)]

# %%
PJW_data = [
(10,0),
(50010,3),
(100010,17),
(150010,46),
(200010,90),
(250010,160),
(300010,241),
(350010,320),
(400010,383),
(450010,570),
(500010,634),
(550010,677),
(600010,899),
(650010,1062),
(700010,1173),
(750010,1448),
(800010,1518),
(850010,1807),
(900010,2022),
(950010,2237)]

# %%
ELF_data = [(10,0),
(50010,8),
(100010,29),
(150010,62),
(200010,96),
(250010,159),
(300010,197),
(350010,330),
(400010,440),
(450010,506),
(500010,568),
(550010,783),
(600010,890),
(650010,1092),
(700010,1215),
(750010,1375),
(800010,1542),
(850010,1818),
(900010,1953),
(950010,2262)]

# %%
BKDR_data = [(10,0),
(50010,0),
(100010,2),
(150010,2),
(200010,6),
(250010,9),
(300010,10),
(350010,12),
(400010,15),
(450010,25),
(500010,36),
(550010,37),
(600010,38),
(650010,43),
(700010,51),
(750010,69),
(800010,72),
(850010,89),
(900010,121),
(950010,97)]

# %%
SDBM_data = [(10,0),
(50010,1),
(100010,0),
(150010,3),
(200010,7),
(250010,4),
(300010,14),
(350010,19),
(400010,17),
(450010,25),
(500010,30),
(550010,35),
(600010,48),
(650010,45),
(700010,58),
(750010,59),
(800010,66),
(850010,87),
(900010,90),
(950010,99)]

# %%
DJB_data = [(10,0),
(50010,1),
(100010,0),
(150010,0),
(200010,6),
(250010,9),
(300010,8),
(350010,16),
(400010,14),
(450010,22),
(500010,26),
(550010,36),
(600010,50),
(650010,40),
(700010,66),
(750010,62),
(800010,69),
(850010,92),
(900010,98),
(950010,103)]

# %%
DEK_data = [(10,0),
(50010,0),
(100010,3),
(150010,7),
(200010,6),
(250010,8),
(300010,14),
(350010,18),
(400010,33),
(450010,45),
(500010,42),
(550010,56),
(600010,71),
(650010,78),
(700010,83),
(750010,108),
(800010,123),
(850010,133),
(900010,158),
(950010,170)]

# %%
AP_data = [(10,0),
(50010,0),
(100010,2),
(150010,3),
(200010,5),
(250010,6),
(300010,9),
(350010,15),
(400010,14),
(450010,27),
(500010,24),
(550010,49),
(600010,43),
(650010,70),
(700010,56),
(750010,66),
(800010,79),
(850010,76),
(900010,105),
(950010,105)]

# %%
X_RS = []
Y_RS = []
for i in range(len(RS_data)):
    X_RS.append(RS_data[i][0])
    Y_RS.append(RS_data[i][1])

# %%
X_JSH = []
Y_JSH = []
for i in range(len(JSH_data)):
    X_JSH.append(JSH_data[i][0])
    Y_JSH.append(JSH_data[i][1])

# %%
X_PJW = []
Y_PJW = []
for i in range(len(PJW_data)):
    X_PJW.append(PJW_data[i][0])
    Y_PJW.append(PJW_data[i][1])

# %%
X_ELF = []
Y_ELF = []
for i in range(len(ELF_data)):
    X_ELF.append(ELF_data[i][0])
    Y_ELF.append(ELF_data[i][1])

# %%
X_BKDR = []
Y_BKDR = []
for i in range(len(BKDR_data)):
    X_BKDR.append(BKDR_data[i][0])
    Y_BKDR.append(BKDR_data[i][1])

# %%
X_SDBM = []
Y_SDBM = []
for i in range(len(SDBM_data)):
    X_SDBM.append(SDBM_data[i][0])
    Y_SDBM.append(SDBM_data[i][1])

# %%
X_DJB = []
Y_DJB = []
for i in range(len(DJB_data)):
    X_DJB.append(DJB_data[i][0])
    Y_DJB.append(DJB_data[i][1])

# %%
X_DEK = []
Y_DEK = []
for i in range(len(DEK_data)):
    X_DEK.append(DEK_data[i][0])
    Y_DEK.append(DEK_data[i][1])

# %%
X_AP = []
Y_AP = []
for i in range(len(AP_data)):
    X_AP.append(AP_data[i][0])
    Y_AP.append(AP_data[i][1])

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_RS, Y_RS, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('RS')
plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_JSH, Y_JSH, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('JSH')
plt.show()

# %%
# PJW
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_PJW, Y_PJW, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('PJW')
plt.show()

# %%
# ELF
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_ELF, Y_ELF, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('ELF')
plt.show()

# %%
# BKDR
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_BKDR, Y_BKDR, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('BKDR')
plt.show()

# %%
# SDBM
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_SDBM, Y_SDBM, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('SDBM')
plt.show()

# %%
# DJB
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_DJB, Y_DJB, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('DJB')
plt.show()

# %%
# DEK
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_DEK, Y_DEK, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('DEK')
plt.show()

# %%
# AP
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_AP, Y_AP, color="grey", markersize=5, marker='o', linestyle='')
ax.grid()
plt.xlabel('Amount of elements')
plt.ylabel('Number of collisions')
plt.title('AP')
plt.show()
